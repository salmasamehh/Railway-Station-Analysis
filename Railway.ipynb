# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


import warnings
warnings.filterwarnings("ignore")
sns.set(rc={'figure.figsize': [12, 12]}, font_scale=1.2)
# %matplotlib inline

# %%
DataFrame=pd.read_csv(r'D:\AI\Projects\NTI Projects\Final Project\Railway Data\Railway Edited Data Excel.csv')
pd.set_option('display.max.columns',None)

# %%
df=DataFrame.copy()
df.head()
# Out:
#             Transaction ID Date of Purchase Time of Purchase  \
# 0  da8a6ba8-b3dc-4677-b176        12/8/2023      12:41:00 PM
# 1  b0cdd1b0-f214-4197-be53       12/16/2023      11:23:00 AM
# 2  f3ba7a96-f713-40d9-9629       12/19/2023       7:51:00 AM
# 3  b2471f11-4fe7-4c87-8ab4       12/20/2023      11:00:00 AM
# 4  2be00b45-0762-485e-a7a3       12/27/2023       6:22:00 AM
#
#   Purchase Time Interval Purchase Type Payment Method Railcard Ticket Class  \
# 0                Evening        Online    Contactless    Adult     Standard
# 1                Morning       Station    Credit Card    Adult     Standard
# 2                Morning        Online    Credit Card      NaN     Standard
# 3                Morning       Station    Credit Card      NaN     Standard
# 4                Morning        Online    Contactless      NaN     Standard
#
#   Ticket Type  Price Departure Station-City Departure Station-Place  \
# 0     Advance     43                 London              Paddington
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31653 entries, 0 to 31652
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Transaction ID            31653 non-null  object
#  1   Date of Purchase          31653 non-null  object
#  2   Time of Purchase          31653 non-null  object
#  3   Purchase Time Interval    31653 non-null  object
#  4   Purchase Type             31653 non-null  object
#  5   Payment Method            31653 non-null  object
#  6   Railcard                  10735 non-null  object
#  7   Ticket Class              31653 non-null  object
#  8   Ticket Type               31653 non-null  object
#  9   Price                     31653 non-null  int64
#  10  Departure Station-City    31653 non-null  object
#  11  Departure Station-Place   29988 non-null  object
#  12  Arrival Destination-City  31653 non-null  object
# ...

# %%
df.describe(include='all')
# Out:
#                  Transaction ID Date of Purchase Time of Purchase  \
# count                     31653            31653            31653
# unique                    31653              128              720
# top     da8a6ba8-b3dc-4677-b176         2/2/2024       8:23:00 AM
# freq                          1              513              188
# mean                        NaN              NaN              NaN
# std                         NaN              NaN              NaN
# min                         NaN              NaN              NaN
# 25%                         NaN              NaN              NaN
# 50%                         NaN              NaN              NaN
# 75%                         NaN              NaN              NaN
# max                         NaN              NaN              NaN
#
#        Purchase Time Interval Purchase Type Payment Method Railcard  \
# count                   31653         31653          31653    10735
# ...

# %%
df.isna().sum()
# Out:
# Transaction ID                  0
# Date of Purchase                0
# Time of Purchase                0
# Purchase Time Interval          0
# Purchase Type                   0
# Payment Method                  0
# Railcard                    20918
# Ticket Class                    0
# Ticket Type                     0
# Price                           0
# Departure Station-City          0
# Departure Station-Place      1665
# Arrival Destination-City        0
# Arrival Destination         11764
# Date of Journey                 0
# Departure Time                  0
# Arrival Time                    0
# Actual Arrival Time          1880
# Arrival Delay                1880
# Journey Time                    0
# Journey Status                  0
# Reason for Delay            27481
# Refund Request                  0
# Days of Purchase                0
# Departure Stations              0
# dtype: int64

# %%
df['Reason for Delay'] = df['Reason for Delay'].fillna('Non Canselled nor Delayed')
df.head()
#Fill nans with Non Canselled nor Delayed
# Out:
#             Transaction ID Date of Purchase Time of Purchase  \
# 0  da8a6ba8-b3dc-4677-b176        12/8/2023      12:41:00 PM
# 1  b0cdd1b0-f214-4197-be53       12/16/2023      11:23:00 AM
# 2  f3ba7a96-f713-40d9-9629       12/19/2023       7:51:00 AM
# 3  b2471f11-4fe7-4c87-8ab4       12/20/2023      11:00:00 AM
# 4  2be00b45-0762-485e-a7a3       12/27/2023       6:22:00 AM
#
#   Purchase Time Interval Purchase Type Payment Method Railcard Ticket Class  \
# 0                Evening        Online    Contactless    Adult     Standard
# 1                Morning       Station    Credit Card    Adult     Standard
# 2                Morning        Online    Credit Card      NaN     Standard
# 3                Morning       Station    Credit Card      NaN     Standard
# 4                Morning        Online    Contactless      NaN     Standard
#
#   Ticket Type  Price Departure Station-City Departure Station-Place  \
# 0     Advance     43                 London              Paddington
# ...

# %%
df.describe(include='all')
# Out:
#                  Transaction ID Date of Purchase Time of Purchase  \
# count                     31653            31653            31653
# unique                    31653              128              720
# top     da8a6ba8-b3dc-4677-b176         2/2/2024       8:23:00 AM
# freq                          1              513              188
# mean                        NaN              NaN              NaN
# std                         NaN              NaN              NaN
# min                         NaN              NaN              NaN
# 25%                         NaN              NaN              NaN
# 50%                         NaN              NaN              NaN
# 75%                         NaN              NaN              NaN
# max                         NaN              NaN              NaN
#
#        Purchase Time Interval Purchase Type Payment Method Railcard  \
# count                   31653         31653          31653    10735
# ...

# %% [markdown]
# ## There is No Outliers in the data, extra data is useful

# %%
# Define a custom palette with gray and yellow
custom_palette = ['#808080', '#FFD700']  # Gray and Yellow

# Create the boxplot with the custom palette and ensure outliers are shown
sns.boxplot(x='Departure Station-City', y='Price', data=df, palette=custom_palette, showfliers=True)

# Show the plot
plt.show()

# %%
df.to_excel("D:\\AI\\Projects\\NTI Projects\\Final Project\\Railway Data.xlsx")
